# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# img = np.load('test_outputs/renderer_fbp.npy')
# img = np.load('test_outputs/renderer_sdf.npy')
img = np.load('test_outputs/renderer_test.npy')

# %%
# %matplotlib notebook

plt.imshow(img)
plt.show()
np.linalg.norm(img)/(img.shape[0]*img.shape[1])
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.00034526698300124393

# %%
def sdf_to_occ(x):
    '''
    Converts sign distance to occupancy for rendering
    '''
    assert isinstance(x, torch.Tensor) and len(x.shape) == 2, 'Input must be a 2D torch tensor'
    return torch.clamp(20*(torch.sigmoid(x) - 0.5),0,1)  # (0,1) -> (-0.5,0.5) -> (-10,10) -> (0,1)

# %%
t = torch.from_numpy(np.linspace(-10,10,1000))

# %%
out = torch.clamp(20*(torch.sigmoid(t) - 0.5),0,1)

# %%
# %matplotlib notebook

plt.plot(t.numpy(),out.numpy())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = torch.Tensor([0.01])
torch.clamp(50*(torch.sigmoid(x) - 0.5),0,1)
# Out:
# tensor([0.1250])

# %%
[0.0, [[0.0,0.1],[1,2]], np.array([0.0,0.1]), np.array([[0.0,0.1],[1,2]])torch.Tensor([[1,2]]), 'abc']
# Out:
#   File "<ipython-input-56-b2d286a9eae3>", line 1
#     [0.0, [[0.0,0.1],[1,2]], np.array([0.0,0.1]), np.array([[0.0,0.1],[1,2]])torch.Tensor([[1,2]]), 'abc']
#                                                                                  ^
# SyntaxError: invalid syntax
