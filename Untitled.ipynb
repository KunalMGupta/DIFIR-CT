# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test1 = np.load('All_results/exp1_results/movie_60_150_nct.npy')

# %%
test2 = np.load('exp1_results/movie_60_150_nct.npy')

# %%
plt.imshow(test1[...,100])
plt.show()
plt.figure()
plt.imshow(test2[...,100])
plt.show()

# %%
fbp = np.load('exp2_results/movie_0_1500_fbp.npy')

# %%
plt.imshow(fbp[...,100])
plt.show()

# %%
nct = np.load('exp2_results/movie_0_1500_nct.npy')

# %%
plt.imshow(nct[...,200])
plt.show()

# %%
gt = np.load('exp2_results/movie_0_0_gt.npy')

# %%
plt.imshow(gt[...,600])
plt.show()

# %%
import os
os.system('zip -r exp3_results.zip exp3_results/')
os.system('zip -r exp2_results.zip exp2_results/')
os.system('zip -r exp1_results.zip exp1_results/')
