# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.load('test_outputs/sdfgt_forward_combine_false.npy')

# %%
# %matplotlib notebook

plt.imshow(img[...,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import os

# %%
os.path.exists('test_outputs')
# Out:
# True

# %%
a = np.array([1,2,3])

# %%
a.dtype == float
# Out:
# False
