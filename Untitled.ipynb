# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fbp = np.load('exp1_results/movie_60_80_fbp.npy')

# %%
plt.imshow(fbp[...,560])
plt.show()

# %%
nct = np.load('exp1_results/movie_60_80_nct.npy')

# %%
plt.imshow(nct[...,560])
plt.show()

# %%
gt = np.load('exp1_results/movie_60_80_gt.npy')

# %%
plt.imshow(gt[...,560])
plt.show()
