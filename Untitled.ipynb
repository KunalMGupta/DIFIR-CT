# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.load('test_outputs/sdfgt_forward_image1.npy')

# %%
# %matplotlib notebook

plt.imshow(img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
