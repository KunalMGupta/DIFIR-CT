# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
from skimage.restoration import (denoise_tv_chambolle, denoise_bilateral,
                                 denoise_wavelet, estimate_sigma)
import warnings
from torch import optim
from torch.optim.lr_scheduler import StepLR
from sklearn.mixture import GaussianMixture
from copy import deepcopy

from config import *
from anatomy import *
from renderer import *
from siren import *
from model import *
from tqdm import tqdm

# %%
config = Config(np.array([[0.5, 0.8]]), TYPE=0, NUM_HEART_BEATS=2.0, NUM_SDFS=2)
# body = Body(config, [Organ(config,[0.6,0.6],0.2,0.2,'pseudo_heart','const2')])
body = Body(config, [Organ(config,[0.6,0.6],0.2,0.2,'pseudo_heart','const2'),
                     Organ(config,[0.3,0.3],0.1,0.1,'simple_sin','const2')])

# body = Body(config, [Organ(config,[0.6,0.6],0.2,0.2,'pseudo_heart','const2'),
#                      Organ(config,[0.3,0.3],0.1,0.1,'const','const2'),
#                      Organ(config,[0.2,0.7],0.1,0.1,'simple_sin','const2')])

# config = Config(np.array([[0.5]]), TYPE=0, NUM_HEART_BEATS=2.0, NUM_SDFS=1)
# body = Body(config, [Organ(config,[0.6,0.6],0.2,0.2,'pseudo_heart','const2')])

# %%
# sinogram, reconstruction_fbp = fetch_fbp_movie(config, body)
# np.save('sinogram',sinogram)
# np.save('reconstruction_fbp',reconstruction_fbp)
sinogram = np.load('sinogram.npy')
reconstruction_fbp = np.load('reconstruction_fbp.npy')

# %%
# %matplotlib notebook
plt.imshow(reconstruction_fbp[...,0])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sdf, init = pretrain_sdf(config,reconstruction_fbp)
# sdf, init = pretrain_sdf(config)
# print(init)
# torch.save(sdf.state_dict(), 'sdf')
# Out:
# Computing Segmentations...
#   0%|          | 1/720 [00:00<01:24,  8.46it/s]
# Computing connected components...
# 100%|██████████| 720/720 [00:01<00:00, 565.47it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Computing SDFs...
# 100%|██████████| 2/2 [02:31<00:00, 87.16s/it]
# itr: 0, loss: 43.4075, lossP: 43.3674, lossE: 0.4008, lr: 1.0000
# /kunal-data/nct_test/NeuralCT/model.py:263: UserWarning: SDF values are in a narrow range between (-1,1)
#   warnings.warn('SDF values are in a narrow range between (-1,1)')
# itr: 200, loss: 1.8014, lossP: 1.7670, lossE: 0.3444, lr: 0.9500
# itr: 400, loss: 1.3157, lossP: 1.2850, lossE: 0.3072, lr: 0.9025
# itr: 600, loss: 1.2561, lossP: 1.2229, lossE: 0.3313, lr: 0.8574
# itr: 800, loss: 1.1168, lossP: 1.0850, lossE: 0.3181, lr: 0.8145

# %%
gt_sinogram = torch.from_numpy(get_sinogram(config, SDFGt(config, body),Intensities(config, learnable = False))).cuda()

# %matplotlib notebook 

plt.imshow(gt_sinogram.detach().cpu().numpy(),cmap='gray')
plt.show()
# Out:
# <div id='c74a8807-a36f-494c-9825-79d7c3b22cb4'></div>

# %%
sdf,intensities = train(config, sdf, gt_sinogram, init=init)
# sdf, _ = pretrain_sdf(config, sdf, lr = 1e-5)
# sdf,intensities  = train(config, sdf, gt_sinogram, lr=1e-5, init=init)
# Out:
# itr: 0, loss: 2.2077, lossP: 2.1724, lossE: 0.2979, lossTVs: 0.5026, lossTVt: 0.0492, lr: 1.0000

# %%
intensities.inty

# %%
with torch.no_grad():
    sinogram = get_sinogram(config, sdf,intensities)
    
# %matplotlib inline
plt.imshow(sinogram,cmap='gray')
plt.show()
plt.figure()
plt.imshow(gt_sinogram.detach().cpu().numpy(),cmap='gray')
plt.show()

# %%
movie = fetch_movie(config, sdf)

# %%
import os
os.system('rm -r movie/ && mkdir movie')
for i in range(movie.shape[2]):
    plt.imsave('movie/{}.png'.format(i), movie[...,i], cmap='gray')
os.system('rm movie.zip && zip -r movie.zip movie/')

# %%
img = sdf(100.0).detach().cpu().numpy()

# %%
# %matplotlib inline
# plt.imshow(movie[...,0],cmap='gray')
plt.imshow(img[...,1]>0)
plt.show()

# %%
# movie[80,80,0]
# Out:
# (128, 128, 2)
